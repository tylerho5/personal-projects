# %%
import HistoryAnalyzer as h

my_history = h.HistoryAnalyzer(current_year = 2024, type = 'graph')
# Out:
# Adding: '\StreamingHistory_music_0.json'
# Adding: '\StreamingHistory_music_1.json'
# Adding: '\StreamingHistory_music_2.json'
# Adding: '\StreamingHistory_music_3.json'
# Data written to "c:\Users\Tyler Ho\Documents\GitHub\personal\Spotify\spotify_history.csv"

# %%
my_history.topSongs()
# Out:
# Top songs of 2024
#                                      Track  Plays
# 1                                  Nights    130
# 2         Witchy (feat. Childish Gambino)    113
# 3                               Like That    108
# 4  act ii: date @ 8 (feat. Drake) - remix    107
# 5                 90210 (feat. Kacy Hill)    105

# %%
my_history.topArtists()

# %%
my_history.totalListeningTime()

# %%
my_history.howManySongs()
# Out:
# 3399 unique songs listened to in 2024

# %%
import SpotifyAPIHandler as s

s1 = s.SpotifyAPIHandler()
s1.getTrackID("Espresso", "Sabrina Carpenter")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import SpotifyAPIHandler as s
#       3 s1 = s.SpotifyAPIHandler()
#       4 s1.getTrackID("Espresso", "Sabrina Carpenter")
#
# ModuleNotFoundError: No module named 'SpotifyAPIHandler'
